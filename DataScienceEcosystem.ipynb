# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
#  # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook there will be a summary of the subject of Data Science Tools and Ecosystem

# %% [markdown]
# Objectives:
# - Popular Languages in Data Science
# - Popular libraries in Data Science
# - Examples of Open Source Environments
# - Simple artihmetic examples of Pyhton

# %% [markdown]
# #### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R language
# 3. SQL
# 4. Julia
# 5. Java

# %% [markdown]
# ### Some of the most used libraries in Data Science are:
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# | Data Science Tools |
# |---|
# | Jupyter Notebook   |
# | R Studio           |
# | Spyder             |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will converts 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Selvet Elif Demirel
